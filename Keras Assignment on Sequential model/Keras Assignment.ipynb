# %%
# Regression Example With diabetes Dataset: sequential model using Keras 
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
# Out:
# Using TensorFlow backend.

# %%
# load dataset
diabete=pd.read_csv('diabetes.csv')
diabete.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# split into input (X) and output (Y) variables
X = diabete.iloc[:,0:3]
Y = diabete.iloc[:,8]

# %%
diabete.shape
# Out:
# (768, 9)

# %%
# create model
model = Sequential()
model.add(Dense(12, input_dim=3, activation='relu'))
    
# Compile model
model.compile(loss='mean_squared_error', optimizer='SGD',  metrics=['accuracy'])

# fit the keras model on the dataset
model.fit(X, Y, epochs=100, batch_size=10)

# evaluate the keras model
_, accuracy = model.evaluate(X, Y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-d740e570b8a4> in <module>
#       7
#       8 # fit the keras model on the dataset
# ----> 9 model.fit(X, Y, epochs=100, batch_size=10)
#      10
#      11 # evaluate the keras model
#
# ~\.conda\envs\tensorflow\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1152             sample_weight=sample_weight,
#    1153             class_weight=class_weight,
# -> 1154             batch_size=batch_size)
#    1155
#    1156         # Prepare validation data.
#
# ~\.conda\envs\tensorflow\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     619                 feed_output_shapes,
#     620                 check_batch_axis=False,  # Don't enforce the batch size.
# --> 621                 exception_prefix='target')
#     622
#     623             # Generate sample-wise weight values given the `sample_weight` and
#
# ~\.conda\envs\tensorflow\lib\site-packages\keras\engine\training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     143                             ': expected ' + names[i] + ' to have shape ' +
#     144                             str(shape) + ' but got array with shape ' +
# --> 145                             str(data_shape))
#     146     return data
#     147
#
# ValueError: Error when checking target: expected dense_19 to have shape (12,) but got array with shape (1,)

# %%
#B.	Build another sequential model where ‘Outcome’ is the dependent variable and all other columns are predictors.
#a.	This model should have 3 hidden layers with 16 nodes in each layer
#b.	Use ‘adam’ as the optimization algorithm
#c.	Fit the model, with number of epochs to be 150 and batch size to be 10

# %%
import livelossplot
plot_losses=livelossplot.PlotLossesKeras()

# %matplotlib inline

# %%
# load the dataset
dataset = pd.read_csv('diabetes.csv')

# split into input (X) and output (y) variables
x = dataset.iloc[:,0:8]
y = dataset.iloc[:,8]

# define the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# compile the keras model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

# fit the keras model on the dataset
model.fit(x, y, epochs=150, batch_size=10)

# evaluate the keras model
_, accuracy = model.evaluate(x, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/150
# 768/768 [==============================] - 0s 256us/step - loss: 0.4971 - accuracy: 0.4766
# Epoch 2/150
# 768/768 [==============================] - 0s 133us/step - loss: 0.3581 - accuracy: 0.5612
# Epoch 3/150
# 768/768 [==============================] - 0s 131us/step - loss: 0.2461 - accuracy: 0.6615
# Epoch 4/150
# 768/768 [==============================] - 0s 126us/step - loss: 0.2343 - accuracy: 0.6745
# Epoch 5/150
# 768/768 [==============================] - 0s 129us/step - loss: 0.2371 - accuracy: 0.6719
# Epoch 6/150
# 768/768 [==============================] - 0s 134us/step - loss: 0.2239 - accuracy: 0.6901
# Epoch 7/150
# 768/768 [==============================] - 0s 131us/step - loss: 0.2199 - accuracy: 0.6888
# Epoch 8/150
# 768/768 [==============================] - 0s 131us/step - loss: 0.2172 - accuracy: 0.6810
# Epoch 9/150
# 768/768 [==============================] - 0s 130us/step - loss: 0.2146 - accuracy: 0.6784
# Epoch 10/150
# 768/768 [==============================] - 0s 129us/step - loss: 0.2119 - accuracy: 0.6836
# Epoch 11/150
# 768/768 [==============================] - 0s 130us/step - loss: 0.2020 - accuracy: 0.6914
# Epoch 12/150
# 768/768 [==============================] - 0s 130us/step - loss: 0.2028 - accuracy: 0.6992
# Epoch 13/150
# 768/768 [==============================] - 0s 176us/step - loss: 0.2085 - accuracy: 0.6992
# Epoch 14/150
# 768/768 [==============================] - 0s 169us/step - loss: 0.1998 - accuracy: 0.7031
# Epoch 15/150
# 768/768 [==============================] - 0s 160us/step - loss: 0.2005 - accuracy: 0.7070
# Epoch 16/150
# 768/768 [==============================] - 0s 134us/step - loss: 0.1996 - accuracy: 0.6927
# Epoch 17/150
# 768/768 [==============================] - 0s 125us/step - loss: 0.1794 - accuracy: 0.7344
# Epoch 49/150
# 768/768 [==============================] - 0s 131us/step - loss: 0.1880 - accuracy: 0.7188
# Epoch 50/150
# 768/768 [==============================] - 0s 139us/step - loss: 0.1788 - accuracy: 0.7474
# Epoch 51/150
# 768/768 [==============================] - 0s 183us/step - loss: 0.1807 - accuracy: 0.7331
# Epoch 52/150
# 768/768 [==============================] - 0s 157us/step - loss: 0.1764 - accuracy: 0.7331
# Epoch 53/150
# 768/768 [==============================] - 0s 170us/step - loss: 0.1741 - accuracy: 0.7435
# Epoch 54/150
# 768/768 [==============================] - 0s 181us/step - loss: 0.1764 - accuracy: 0.7344
# Epoch 55/150
# 768/768 [==============================] - 0s 167us/step - loss: 0.1745 - accuracy: 0.7370
# Epoch 56/150
# 768/768 [==============================] - 0s 168us/step - loss: 0.1781 - accuracy: 0.7292
# Epoch 57/150
# 768/768 [==============================] - 0s 154us/step - loss: 0.1726 - accuracy: 0.7435
# Epoch 58/150
# 768/768 [==============================] - 0s 159us/step - loss: 0.1739 - accuracy: 0.7500
# Epoch 59/150
# 768/768 [==============================] - 0s 159us/step - loss: 0.1725 - accuracy: 0.7435
# Epoch 60/150
# 768/768 [==============================] - 0s 165us/step - loss: 0.1762 - accuracy: 0.7370
# Epoch 61/150
# 768/768 [==============================] - 0s 159us/step - loss: 0.1778 - accuracy: 0.7422
# Epoch 62/150
# 768/768 [==============================] - 0s 164us/step - loss: 0.1745 - accuracy: 0.7344
# Epoch 63/150
# 768/768 [==============================] - 0s 129us/step - loss: 0.1784 - accuracy: 0.7396
# Epoch 64/150
# 768/768 [==============================] - 0s 121us/step - loss: 0.1747 - accuracy: 0.7435
# Epoch 65/150
# 768/768 [==============================] - 0s 131us/step - loss: 0.1745 - accuracy: 0.7422
# Epoch 66/150
# 768/768 [==============================] - 0s 177us/step - loss: 0.1765 - accuracy: 0.7422
# Epoch 67/150
# 768/768 [==============================] - 0s 143us/step - loss: 0.1726 - accuracy: 0.7357
# Epoch 68/150
# 768/768 [==============================] - 0s 152us/step - loss: 0.1718 - accuracy: 0.7409
# Epoch 69/150
# 768/768 [==============================] - 0s 169us/step - loss: 0.1699 - accuracy: 0.7396
# Epoch 70/150
# 768/768 [==============================] - 0s 155us/step - loss: 0.1709 - accuracy: 0.7565
# Epoch 71/150
# 768/768 [==============================] - 0s 113us/step - loss: 0.1687 - accuracy: 0.7474
# Epoch 72/150
# 440/768 [================>.............] - ETA: 0s - loss: 0.1731 - accuracy: 0.7386

# %%
# Compile model
model.compile(loss='mean_squared_error', optimizer='Stochastic Gradient'
 model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#train model
model.fit(X, Y,
         batch_size=10,
         epochs=150,
         callbacks=[plot_losses], 
         verbose=1,
         validation_data=(X, Y)

score=model.evaluate(X, Y, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %%
# Compile model
model.compile(loss='mean_squared_error', optimizer='adam')
return model

# %%
# evaluate model
estimator = KerasRegressor(build_fn=baseline_model, epochs=100, batch_size=10, verbose=0)
kfold = KFold(n_splits=10)
results = cross_val_score(estimator, X, Y, cv=kfold)
print("Baseline")

# %%
import livelossplot
plot_losses=livelossplot.PlotLossesKeras()

# %matplotlib inline
NUM_ROWS=28
NUM_COLS=28
NUM_CLASSES=10
BATCH_SIZE=10
EPOCHS=100
